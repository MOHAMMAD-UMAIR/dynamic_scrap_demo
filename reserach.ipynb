# %%
! pip install langchain
# Out:
# ...
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#    ---------------------------------------- 0.0/798.0 kB ? eta -:--:--
#    ---- ----------------------------------- 81.9/798.0 kB 4.8 MB/s eta 0:00:01
#    ------ --------------------------------- 122.9/798.0 kB 2.4 MB/s eta 0:00:01
#    ------------- -------------------------- 276.5/798.0 kB 2.4 MB/s eta 0:00:01
#    ------------------- -------------------- 389.1/798.0 kB 2.7 MB/s eta 0:00:01
#    ------------------------- -------------- 501.8/798.0 kB 2.6 MB/s eta 0:00:01
#    -------------------------------- ------- 645.1/798.0 kB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 747.5/798.0 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 798.0/798.0 kB 2.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/365.5 kB ? eta -:--:--
#    ------ --------------------------------- 61.4/365.5 kB 3.4 MB/s eta 0:00:01
# ...

# %%
! pip install langchain_openai
# Out:
# ...
#    ---------------------------------------- 0.0/224.7 kB ? eta -:--:--
#    ---------------- ----------------------- 92.2/224.7 kB 2.6 MB/s eta 0:00:01
#    ------------------------------ --------- 174.1/224.7 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 224.7/224.7 kB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/786.4 kB ? eta -:--:--
#    ----- ---------------------------------- 112.6/786.4 kB 3.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 225.3/786.4 kB 2.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 337.9/786.4 kB 3.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 337.9/786.4 kB 3.0 MB/s eta 0:00:01
#    ------------------------ --------------- 481.3/786.4 kB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 614.4/786.4 kB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 757.8/786.4 kB 2.4 MB/s eta 0:00:01
# ...

# %%
gpt_api_key : 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
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 gpt_api_key
#
# NameError: name 'gpt_api_key' is not defined

# %%
import sys
import requests
import hashlib
from bs4 import BeautifulSoup
from datetime import datetime


def get_soup(link):
    """
    Return the BeautifulSoup object for input link
    """
    request_object = requests.get(link, auth=('user', 'pass'))
    soup = BeautifulSoup(request_object.content, "lxml")
    return soup

def get_status_code(link):
    """
    Return the error code for any url
    param: link
    """
    try:
        error_code = requests.get(link).status_code
    except requests.exceptions.ConnectionError:
        error_code = -1
    return error_code

def find_internal_urls(main_url, depth=0, max_depth=2):
    all_urls_info = []

    soup = get_soup(main_url)
    a_tags = soup.findAll("a", href=True)

    if main_url.endswith("/"):
        domain = main_url
    else:
        domain = "/".join(main_url.split("/")[:-1])
    print(domain)
    if depth > max_depth:
        return {}
    else:
        for a_tag in a_tags:
            if "http://" not in a_tag["href"] and "https://" not in a_tag["href"] and "/" in a_tag["href"]:
                url = domain + a_tag['href']
            elif "http://" in a_tag["href"] or "https://" in a_tag["href"]:
                url = a_tag["href"]
            else:
                continue
            # print(url)

            status_dict = {}
            status_dict["url"] = url
            status_dict["status_code"] = get_status_code(url)
            status_dict["timestamp"] = datetime.now()
            status_dict["depth"] = depth + 1
            all_urls_info.append(status_dict)
            print(status_dict)
    return all_urls_info


if __name__ == "__main__":
    url = 'https://www.fortinet.com/'# your domain here
    depth = 1
    all_page_urls = find_internal_urls(url, 0, 2)
    # print("\n\n",all_page_urls)
    if depth > 1:
        for status_dict in all_page_urls:
            find_internal_urls(status_dict['url'])
# Out:
# https://www.fortinet.com/
# {'url': 'https://www.fortinet.com//demo-center', 'status_code': 200, 'timestamp': datetime.datetime(2024, 1, 10, 11, 5, 18, 559436), 'depth': 1}
# {'url': 'https://www.fortinet.com//support/product-downloads', 'status_code': 200, 'timestamp': datetime.datetime(2024, 1, 10, 11, 5, 20, 483718), 'depth': 1}
# {'url': 'https://site.fortinet.com/one/login', 'status_code': 200, 'timestamp': datetime.datetime(2024, 1, 10, 11, 5, 25, 428411), 'depth': 1}
# {'url': 'https://www.fortinet.com', 'status_code': 200, 'timestamp': datetime.datetime(2024, 1, 10, 11, 5, 26, 557380), 'depth': 1}
# {'url': 'https://www.fortinet.com/uk', 'status_code': 200, 'timestamp': datetime.datetime(2024, 1, 10, 11, 5, 27, 687927), 'depth': 1}
# {'url': 'https://www.fortinet.com/de', 'status_code': 200, 'timestamp': datetime.datetime(2024, 1, 10, 11, 5, 28, 863996), 'depth': 1}
# ...

# %%
# Saving the csv file 
import pandas as pd

URL_data= pd.DataFrame(all_page_urls)
URL_data.to_csv('Fortinet_link.csv', index=False)

# %%
URL_data['url'].to_csv('Fortinet_links_only.csv', index=False)

# %% [markdown]
# # Using Langchain for finding the  link of product information

# %%
! export OPENAI_API_KEY="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"
# Out:
# 'export' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(openai_api_key="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")

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are world class lead generator"),
    ("user", "{input} ")
])

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser

# %% [markdown]
# #### Getting the data from the web link

# %%
import requests
from bs4 import BeautifulSoup

URL='https://www.fortinet.com/products'

response = requests.get(URL)
soup = BeautifulSoup(response.text, 'html.parser')

# Extract text content from the HTML body
product_table = soup.find('div', class_= "product-table")
product_text = product_table.text

# %%
product_text
# Out:
# '\n\nApplication Delivery Controllers - FortiADC\n\n\n\nFortiAIOps: Artificial Intelligence for IT Operations\n\n\n\nFortiAnalyzer\n\n\n\nNetwork Authentication - FortiAuthenticator\n\n\n\nNetwork Based Video Security - FortiCam/FortiRecorder\n\n\n\nCloud Access Security Broker\n\n\n\nFortiClient VPN & ZTNA Agent\n\n\n\nFortiConverter Service for Firewall Migration\n\n\n\nFortiCNP\n\n\n\nFortiDDoS – DDoS Protection Solution\n\n\n\nFortiDeceptor\n\n\n\nFortiDevSec\n\n\n\nDynamic Application Security Testing (DAST)\n\n\n\nFortiEDR\n\n\n\nEmail Security\n\n\n\nEthernet Switching\n\n\n\nFortiGate Cloud\n\n\n\nFortiGate Cloud-Native Firewall\n\n\n\nFortiGuard AI-powered Security Services\n\n\n\nIdentity and Access Management\n\n\n\nIPS\n\n\n\nFortiIsolator\n\n\n\nFortiLAN Cloud\n\n\n\nLTE/5G Wireless WAN\n\n\n\nFortiManager\n\n\n\nFortiMonitor \n\n\n\nNAC and IoT Security\n\n\n\nFortiNDR for Network Detection and Response\n\n\n\nEntry Level Next Generation Firewalls\n\n\n\nMid-Range Next-
# ...

# %%
from read_webpage import *
URL='https://www.fortinet.com/products'

web_data=get_website_content(URL)
print(web_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from read_webpage import *
#       2 URL='https://www.fortinet.com/products'
#       4 web_data=get_website_content(URL)
#
# File c:\Users\umair\dynamic_scrap_demo\read_webpage.py:24
#      22 # Example usage
#      23 url = 'https://www.fortinet.com/products'
# ---> 24 website_content = get_website_content(url)
#      26 if website_content:
#      27     print(f"Text content of the HTML body of {url}:\n{website_content}")
#
# File c:\Users\umair\dynamic_scrap_demo\read_webpage.py:15, in get_website_content(url)
#      13     # Extract text content from the HTML body
#      14     product_table = soup.find('div', class_= "product-table")
# ---> 15     product_text = product_table.text()
#      17     return product_text
#      18 else:
#
# TypeError: 'str' object is not callable

# %%
import re
striped_string= re.sub(r'\n\s+', '\n', product_text)
print(striped_string)
# Out:
# Application Delivery Controllers - FortiADC
# FortiAIOps: Artificial Intelligence for IT Operations
# FortiAnalyzer
# Network Authentication - FortiAuthenticator
# Network Based Video Security - FortiCam/FortiRecorder
# Cloud Access Security Broker
# FortiClient VPN & ZTNA Agent
# FortiConverter Service for Firewall Migration
# FortiCNP
# FortiDDoS – DDoS Protection Solution
# FortiDeceptor
# FortiDevSec
# Dynamic Application Security Testing (DAST)
# FortiEDR
# Email Security
# Ethernet Switching
# FortiGate Cloud
# FortiGate Cloud-Native Firewall
# FortiGuard AI-powered Security Services
# Identity and Access Management
# IPS
# FortiIsolator
# FortiLAN Cloud
# LTE/5G Wireless WAN
# FortiManager
# FortiMonitor
# NAC and IoT Security
# FortiNDR for Network Detection and Response
# Entry Level Next Generation Firewalls
# Mid-Range Next-Generation Firewalls
# High-End Next Generation Firewalls
# Ultra High-End Next Generation Firewalls
# Chassis-Based Next-Generation Firewalls
# ...

# %%
promt_text1 = f"find the total number of products and their names based on this website text data: {striped_string}"
response1= chain.invoke({'input': promt_text1})

# %%
print(response1)
# Out:
# Based on the provided website text data, the total number of products is 46. Here are the names of the products:
#
# 1. Application Delivery Controllers - FortiADC
# 2. FortiAIOps: Artificial Intelligence for IT Operations
# 3. FortiAnalyzer
# 4. Network Authentication - FortiAuthenticator
# 5. Network Based Video Security - FortiCam/FortiRecorder
# 6. Cloud Access Security Broker
# 7. FortiClient VPN & ZTNA Agent
# 8. FortiConverter Service for Firewall Migration
# 9. FortiCNP
# 10. FortiDDoS – DDoS Protection Solution
# 11. FortiDeceptor
# 12. FortiDevSec
# 13. Dynamic Application Security Testing (DAST)
# 14. FortiEDR
# 15. Email Security
# 16. Ethernet Switching
# 17. FortiGate Cloud
# 18. FortiGate Cloud-Native Firewall
# 19. FortiGuard AI-powered Security Services
# 20. Identity and Access Management
# 21. IPS
# 22. FortiIsolator
# 23. FortiLAN Cloud
# 24. LTE/5G Wireless WAN
# 25. FortiManager
# 26. FortiMonitor
# 27. NAC and IoT Security
# ...

# %% [markdown]
# #### filtering the links based on product names and then prompting GPT to pick up the link

# %%
import pandas as pd

# Load the Excel file into a DataFrame
file_path = 'Fortinet_links_only.csv'
df = pd.read_csv(file_path, header=None, names=['URL'])

# Filter URLs containing the word "products"
filtered_urls = df[df['URL'].str.contains('products')]

# Print the filtered URLs
print("Filtered URLs with 'products':")
for url in filtered_urls['URL'].tolist():
    print(url)
# Out:
# Filtered URLs with 'products':
# https://www.fortinet.com//products/next-generation-firewall
# https://www.fortinet.com//products/private-cloud-security/fortigate-virtual-appliances
# https://www.fortinet.com//products/public-cloud-security/cloud-native-firewall
# https://www.fortinet.com//products/management/fortimanager
# https://www.fortinet.com//products/next-generation-firewall/forticonverter
# https://www.fortinet.com//products/sd-wan
# https://www.fortinet.com//products/sase
# https://www.fortinet.com//products/secure-web-gateway/fortiproxy
# https://www.fortinet.com//products/endpoint-security/forticlient
# https://www.fortinet.com//products/identity-access-management
# https://www.fortinet.com//products/fortitrust-identity
# https://www.fortinet.com//products/fortipam
# https://www.fortinet.com//products/management/fortimanager
# https://www.fortinet.com//products/fortimonitor
# https://www.fortinet.com//products/ethernet-switches
# ...

# %%
url_list=filtered_urls['URL'].tolist()
print(url_list)
# Out:
# ['https://www.fortinet.com//products/next-generation-firewall', 'https://www.fortinet.com//products/private-cloud-security/fortigate-virtual-appliances', 'https://www.fortinet.com//products/public-cloud-security/cloud-native-firewall', 'https://www.fortinet.com//products/management/fortimanager', 'https://www.fortinet.com//products/next-generation-firewall/forticonverter', 'https://www.fortinet.com//products/sd-wan', 'https://www.fortinet.com//products/sase', 'https://www.fortinet.com//products/secure-web-gateway/fortiproxy', 'https://www.fortinet.com//products/endpoint-security/forticlient', 'https://www.fortinet.com//products/identity-access-management', 'https://www.fortinet.com//products/fortitrust-identity', 'https://www.fortinet.com//products/fortipam', 'https://www.fortinet.com//products/management/fortimanager', 'https://www.fortinet.com//products/fortimonitor', 'https://www.fortinet.com//products/ethernet-switches', 'https://www.fortinet.com//products/wireless-access-points'
# ...

# %%
str(filtered_urls['URL'])
# Out:
# '17     https://www.fortinet.com//products/next-genera...\n18     https://www.fortinet.com//products/private-clo...\n19     https://www.fortinet.com//products/public-clou...\n27     https://www.fortinet.com//products/management/...\n28     https://www.fortinet.com//products/next-genera...\n                             ...                        \n368    https://www.fortinet.com//products/web-applica...\n370    https://www.fortinet.com//products/management/...\n411    https://www.fortinet.com//trust?tab=trusted%20...\n471    https://www.fortinet.com//trust?tab=trusted%20...\n510    https://www.fortinet.com//trust?tab=trusted%20...\nName: URL, Length: 92, dtype: object'

# %%
//*[@id="product-table"]/div[1]
//*[@id="product-table"]/div[53]

# %%
promt_text2 = f"Pick one link for every product listed in this list {response1} which you are sure that will be the product description pages, from the list of links : {url_list}"
response2= chain.invoke({'input': promt_text2})

# %%
print(response2)
# Out:
# Based on the provided website text data, here are the links for each product:
#
# 1. Application Delivery Controllers - FortiADC: [https://www.fortinet.com//products/application-delivery-controller/fortiadc](https://www.fortinet.com//products/application-delivery-controller/fortiadc)
# 2. FortiAIOps: Artificial Intelligence for IT Operations: [https://www.fortinet.com//products/fortiaiops](https://www.fortinet.com//products/fortiaiops)
# 3. FortiAnalyzer: [https://www.fortinet.com//products/management/fortianalyzer](https://www.fortinet.com//products/management/fortianalyzer)
# 4. Network Authentication - FortiAuthenticator: [https://www.fortinet.com//products/identity-access-management](https://www.fortinet.com//products/identity-access-management)
# 5. Network Based Video Security - FortiCam/FortiRecorder: [https://www.fortinet.com//products/network-based-video-security/forticam-fortirecorder](https://www.fortinet.com//products/network-based-video-security/forticam-fortirecorder)
# ...

# %%
print(response)
# Out:
# Based on the provided website text data, the total number of products is 48. Here are their names:
#
# 1. Application Delivery Controllers - FortiADC
# 2. FortiAIOps: Artificial Intelligence for IT Operations
# 3. FortiAnalyzer
# 4. Network Authentication - FortiAuthenticator
# 5. Network Based Video Security - FortiCam/FortiRecorder
# 6. Cloud Access Security Broker
# 7. FortiClient VPN & ZTNA Agent
# 8. FortiConverter Service for Firewall Migration
# 9. FortiCNP
# 10. FortiDDoS – DDoS Protection Solution
# 11. FortiDeceptor
# 12. FortiDevSec
# 13. Dynamic Application Security Testing (DAST)
# 14. FortiEDR
# 15. Email Security
# 16. Ethernet Switching
# 17. FortiGate Cloud
# 18. FortiGate Cloud-Native Firewall
# 19. FortiGuard AI-powered Security Services
# 20. Identity and Access Management
# 21. IPS
# 22. FortiIsolator
# 23. FortiLAN Cloud
# 24. LTE/5G Wireless WAN
# 25. FortiManager
# 26. FortiMonitor
# 27. NAC and IoT Security
# 28. FortiNDR for Network Detection and Response
# ...

# %% [markdown]
# ##### Gathering the web page data

# %%
URL='https://www.fortinet.com/products/application-delivery-controller/fortiadc'

response = requests.get(URL)
soup = BeautifulSoup(response.text, 'html.parser')


# Extract text content from the HTML body
page_content = soup.find('main', class_= "page--body")
page_text = page_content.text

# Cleaning the text
striped_page_text= re.sub(r'\n\s+', '\n', page_text)
print(striped_page_text)
# Out:
# Application Delivery Controller and GSLB
# FortiADC and FortiGSLB Cloud optimize application delivery
# Free Product Demo
# Download Solution Brief
# Overview
# Security Services
# Case Studies & Reviews
# Models & Specs
# Support & Services
# Resources
# FREE DEMO
# Overview
# FREE DEMO
# Overview
# Security Services
# Case Studies & Reviews
# Models & Specs
# Support & Services
# Resources
# Overview
# FortiADC enhances the scalability, performance, and security of your applications whether they are hosted on-premises or in the cloud. Our advanced application delivery controller optimizes application performance and availability while securing the application with both its native security tools and by integrating application delivery into the Fortinet Security Fabric.
# Unmatched Application Acceleration
# ...

# %%
striped_page_text
# Out:
# "\nApplication Delivery Controller and GSLB\nFortiADC and FortiGSLB Cloud optimize application delivery\nFree Product Demo\nDownload Solution Brief\nOverview\nSecurity Services\nCase Studies & Reviews\nModels & Specs\nSupport & Services\nResources\nFREE DEMO\nOverview\nFREE DEMO\nOverview\nSecurity Services\nCase Studies & Reviews\nModels & Specs\nSupport & Services\nResources\nOverview\nFortiADC enhances the scalability, performance, and security of your applications whether they are hosted on-premises or in the cloud. Our advanced application delivery controller optimizes application performance and availability while securing the application with both its native security tools and by integrating application delivery into the Fortinet Security Fabric.\nUnmatched Application Acceleration\nFortiADC provides unmatched application acceleration, load balancing, and web security, regardless of whether it is used for applications within a single data center or serves multiple applications
# ...

# %% [markdown]
# #### Prompt for product definition

# %%
promt_text3 = f"Write a product description based on MITRE ATT&CK pattern of 'Application Delivery Controller and GSLB' from the information given in this text document:{striped_page_text}"
response3= chain.invoke({'input': promt_text3})

# %%
print(response3)
# Out:
# Introducing the FortiADC and FortiGSLB Cloud, the ultimate solution for optimizing application delivery and ensuring business continuity. With our advanced application delivery controller, FortiADC, and our DNS-based service, FortiGSLB Cloud, you can enhance the scalability, performance, and security of your applications, whether they are hosted on-premises or in the cloud.
#
# FortiADC offers unmatched application acceleration, load balancing, and web security, making it the perfect solution for applications within a single data center or serving millions of users globally. It includes application acceleration, WAF, IPS, SSLi, link load balancing, and user authentication in one comprehensive solution. With FortiADC, you can achieve availability, performance, and security in a single, all-inclusive license.
#
# ...

# %%
promt_text4 = f"List the matching MITRE ATT&CK techniques which this product would be able stop : {response3}"
response4= chain.invoke({'input': promt_text4})

# %%
print(response4)
# Out:
# and virtual appliances, to meet the needs of any organization. With its comprehensive set of features and benefits, FortiADC and FortiGSLB Cloud can effectively stop or mitigate the following MITRE ATT&CK techniques:
#
# 1. T1071 - Application Layer Protocol: FortiADC can inspect and filter application layer protocols to ensure secure and authorized communication.
#
# 2. T1100 - Web Service: FortiADC includes a web application firewall (WAF) that can protect against web-based attacks and vulnerabilities.
#
# 3. T1102 - Web Service Connection: FortiADC can load balance and distribute web service connections to optimize performance and availability.
#
# 4. T1105 - Remote File Copy: FortiADC's security features, such as SSL forward proxy and IP reputation, can prevent unauthorized remote file copies.
#
# 5. T1134 - Access Token Manipulation: FortiADC's user authentication capabilities can prevent access token manipulation and unauthorized access.
#
# ...
